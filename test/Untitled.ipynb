# %%
import schemdraw
from schemdraw.parsing import logicparse
schemdraw.use('svg')

# %%
logicparse('(not a) and b or c', gateH=.5)  # gateH=0.5 makes them line up nicer when there's only one child
# Out:
# None style="stroke:black;stroke-width:2;stroke-linecap:round;stroke-linejoin:round;"
# None style="stroke:black;stroke-width:2;stroke-linecap:round;stroke-linejoin:round;"
# None style="stroke:black;stroke-width:2;stroke-linecap:round;stroke-linejoin:round;"
# None style="stroke:black;stroke-width:2;stroke-linecap:round;stroke-linejoin:round;"
# None style="stroke:black;stroke-width:2;stroke-linecap:round;stroke-linejoin:round;"
# None style="stroke:black;stroke-width:2;stroke-linecap:round;stroke-linejoin:round;"
# None style="stroke:black;stroke-width:2;stroke-linecap:round;stroke-linejoin:round;"
# None style="stroke:black;stroke-width:2;stroke-linecap:round;stroke-linejoin:round;"
# None style="stroke:black;stroke-width:2;stroke-linecap:round;stroke-linejoin:round;"
# None style="stroke:black;stroke-width:2;stroke-linecap:round;stroke-linejoin:round;"
# None style="stroke:black;stroke-width:2;stroke-linecap:round;stroke-linejoin:round;"
# None style="stroke:black;stroke-width:2;"
# None style="stroke:black;stroke-width:2;stroke-linecap:round;stroke-linejoin:round;"
# None style="stroke:black;stroke-width:2;stroke-linecap:round;stroke-linejoin:round;"
