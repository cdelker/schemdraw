# %%
# Draw all defined dsp elements, with color and fill

# %%
import schemdraw
import schemdraw.elements as elm
from schemdraw import dsp
schemdraw.use('svg')

# %%
def drawElements(elm_list, n=5, dx=1, dy=2, ofst=.8, fname=None, **kwargs):
    x, y = 0, 0
    d = schemdraw.Drawing(fontsize=12)
    for e in elm_list:
        element = getattr(dsp, e)
        d += element().at(((d.unit+1)*x+1,y)).label(e, loc='top', ofst=.1)
        x = x + dx
        if x >= n:
            x=0
            y=y-dy
    return d

elist = ['Square', 'Demod', 'Mixer', 'Filter', 'Oscillator', 'OscillatorBox',
         'Sum', 'SumSigma', 'Adc', 'Dac', 'Speaker', 'Amp', 'Circulator', 'Isolator', 'VGA']

# %%
display(drawElements(elist, d='right'))

# %%
display(drawElements(elist, d='right', fill='yellow'))

# %%
display(drawElements(elist, d='right', color='blue'))

# %%
dsp.Mixer(N='a', S='b', W='c', E='d')

# %%
dsp.Mixer(N='a', S='b', W='c', E='d', fontsize=15).scale(2)

# %%
with schemdraw.Drawing() as d:
    elm.Arrow().length(d.unit/2).label('$E_i(s)$')
    mx = dsp.Mixer(W='+', S='–')
    elm.Arrow().length(d.unit/2)
    dsp.Square().label(r'1/R').anchor('W')
    elm.Arrow().length(d.unit/2).label('$I(s)$')
    d.move(0, -d.unit)
    elm.Line().left().tox(mx.S)
    elm.Arrow().up().toy(mx.S).label('$E_o(s)$')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" height="144.84399999999997pt" width="243.20000000000005pt" viewBox="-4.6 -26.844 243.20000000000005 144.84399999999997"><circle cx="72" cy="-0" r="18" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;" /><path d="M 0.0,-0.0 L 27,-0 L 45,-0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 52 0 L 45 2.7 L 45 -2.7 Z" style="stroke:black;fill:black;stroke-linecap:butt;stroke-linejoin:miter;" /><path d="M 84.72792206135786,-12.727922061357857 L 59.272,12.728" style="stroke:black;fill:none;stroke-width:1;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 84.72792206135786,12.727922061357857 L 59.272,-12.728" style="stroke:black;fill:none;stroke-width:1;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 90.0,-0.0 L 117,-0 L 135,-0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 142 0 L 135 2.7 L 135 -2.7 Z" style="stroke:black;fill:black;stroke-linecap:butt;stroke-linejoin:miter;" /><path d="M 144.0,-0.0 L 144,-18 L 180,-18 L 180,18 L 144,18 L 144,-0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 180.0,-0.0 L 207,-0 L 225,-0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 232 0 L 225 2.7 L 225 -2.7 Z" style="stroke:black;fill:black;stroke-linecap:butt;stroke-linejoin:miter;" /><path d="M 234.0,108.0 L 153,108 L 72,108" style="stroke:black;fill:none;st