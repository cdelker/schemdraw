# %%
# Various canvas options

import schemdraw
from schemdraw import elements as elm

import matplotlib.pyplot as plt
from xml.etree import ElementTree as ET

# %%
schemdraw.debug()

# %%
schemdraw.use('matplotlib')
elm.Resistor().label(r'1$\Omega$')

# %%
with schemdraw.Drawing() as d:
    d += elm.Resistor().label(r'1$\Omega$')

# %%
# No figure should be drawn
with schemdraw.Drawing(show=False) as d:
    d += elm.Resistor().label(r'1$\Omega$')

# %%
schemdraw.use('svg')
with schemdraw.Drawing() as d:
    d += elm.Resistor().label(r'1$\Omega$')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" height="40.166000000000004pt" width="117.2pt" viewBox="-4.6 -26.566 117.2 40.166000000000004"><rect x="-4.6" y="-26.566" width="117.19999999999999" height="40.166" style="fill:none; stroke-width:0.5; stroke:black;" /><rect x="0.0" y="-21.965999999999998" width="108.0" height="30.965999999999998" style="fill:none; stroke-width:1; stroke:red;" /><path d="M 0.0,-0.0 L 36.0,-0.0 L 39.0,-9.0 L 45.0,9.0 L 50.99999999999999,-9.0 L 57.0,9.0 L 63.0,-9.0 L 69.0,9.0 L 72.0,-0.0 L 108.0,-0.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 0.0,9.0 L 108.0,9.0 L 108.0,-21.965999999999998 L 0.0,-21.965999999999998 L 0.0,9.0" style="stroke:blue;fill:none;stroke-width:0.5;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><g><g><g><symbol id="STIXTwoMathRegular_4244" viewBox="0 -31.524 3.756 51.216"><path d="M 3.75
# ...

# %%
# No figure should be drawn
with schemdraw.Drawing(show=False) as d:
    d += elm.Resistor().label(r'1$\Omega$')

# %%
elm.Resistor().label(r'1$\Omega$')

# %%
with schemdraw.Drawing(canvas='svg') as d:
    d += elm.Resistor().label(r'1$\Omega$')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" height="40.166000000000004pt" width="117.2pt" viewBox="-4.6 -26.566 117.2 40.166000000000004"><rect x="-4.6" y="-26.566" width="117.19999999999999" height="40.166" style="fill:none; stroke-width:0.5; stroke:black;" /><rect x="0.0" y="-21.965999999999998" width="108.0" height="30.965999999999998" style="fill:none; stroke-width:1; stroke:red;" /><path d="M 0.0,-0.0 L 36.0,-0.0 L 39.0,-9.0 L 45.0,9.0 L 50.99999999999999,-9.0 L 57.0,9.0 L 63.0,-9.0 L 69.0,9.0 L 72.0,-0.0 L 108.0,-0.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 0.0,9.0 L 108.0,9.0 L 108.0,-21.965999999999998 L 0.0,-21.965999999999998 L 0.0,9.0" style="stroke:blue;fill:none;stroke-width:0.5;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><g><g><g><symbol id="STIXTwoMathRegular_4244" viewBox="0 -31.524 3.756 51.216"><path d="M 3.75
# ...

# %%
with schemdraw.Drawing(canvas='matplotlib') as d:
    d += elm.Resistor().label(r'1$\Omega$')

# %%
fig, ax = plt.subplots()
ax.plot([0,1,2,3,4,5],[0,1,0,-1,0,1], marker='o', ls='')
ax.set_aspect('equal')
with schemdraw.Drawing(canvas=ax) as d:
    elm.Resistor()

# %%
svg = ET.Element('svg')
svg.set('xmlns', 'http://www.w3.org/2000/svg')
svg.set('xml:lang', 'en')
svg.set('height', f'100')
svg.set('width', f'300')
svg.set('viewBox', f'0 0 300 100')
circ = ET.SubElement(svg, 'circle')
circ.set('cx', '20')
circ.set('cy', '25')
circ.set('r', '25')
circ.set('fill', 'orange')

with schemdraw.Drawing(canvas=svg) as d:
    d.config(inches_per_unit=.5)
    d += elm.Resistor().label(r'1$\Omega$').at((1,-1))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xml:lang="en" height="100" width="300" viewBox="0 0 300 100"><circle cx="20" cy="25" r="25" fill="orange" /><rect x="31.4" y="9.434000000000001" width="117.20000000000002" height="40.166" style="fill:none; stroke-width:0.5; stroke:black;" /><rect x="36.0" y="14.034" width="108.0" height="30.966" style="fill:none; stroke-width:1; stroke:red;" /><path d="M 36.0,36.0 L 72.0,36.0 L 74.99999999999999,27.0 L 81.0,45.0 L 87.0,27.0 L 92.99999999999999,45.0 L 99.0,27.0 L 105.0,45.0 L 108.0,36.0 L 144.0,36.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 36.0,45.0 L 144.0,45.0 L 144.0,14.034 L 36.0,14.034 L 36.0,45.0" style="stroke:blue;fill:none;stroke-width:0.5;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><g><g><g><symbol id="STIXTwoMathRegular_4244" viewBox="0 -31.524 3.756 51.216"><path d="M 3.756 0 L 3.756 0 L 2.76 0 L 2.76 -6.348 L 1.212 -6.348 L 1.21
# ...

# %%
d = schemdraw.Drawing()
d += elm.Resistor()
d.draw(canvas='svg')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" height="27.2pt" width="117.2pt" viewBox="-4.6 -13.6 117.2 27.2"><rect x="-4.6" y="-13.6" width="117.19999999999999" height="27.2" style="fill:none; stroke-width:0.5; stroke:black;" /><rect x="0.0" y="-9.0" width="108.0" height="18.0" style="fill:none; stroke-width:1; stroke:red;" /><path d="M 0.0,-0.0 L 36.0,-0.0 L 39.0,-9.0 L 45.0,9.0 L 50.99999999999999,-9.0 L 57.0,9.0 L 63.0,-9.0 L 69.0,9.0 L 72.0,-0.0 L 108.0,-0.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 0.0,9.0 L 108.0,9.0 L 108.0,-9.0 L 0.0,-9.0 L 0.0,9.0" style="stroke:blue;fill:none;stroke-width:0.5;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /></svg>

# %%
d = schemdraw.Drawing()
d += elm.Resistor()
d.draw(canvas='matplotlib')

# %%
schemdraw.config(fontsize=26)
with schemdraw.Drawing(canvas='matplotlib') as d:
    elm.Resistor().label('$R_2$', loc='top')

# %%
schemdraw.svgconfig.text = 'path'
with schemdraw.Drawing(canvas='svg') as d:
    elm.Resistor().label('$R_2$', loc='top')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" height="53.342pt" width="117.2pt" viewBox="-4.6 -39.742 117.2 53.342"><rect x="-4.6" y="-39.742" width="117.19999999999999" height="53.342" style="fill:none; stroke-width:0.5; stroke:black;" /><rect x="0.0" y="-35.141999999999996" width="108.0" height="44.141999999999996" style="fill:none; stroke-width:1; stroke:red;" /><path d="M 0.0,-0.0 L 36.0,-0.0 L 39.0,-9.0 L 45.0,9.0 L 50.99999999999999,-9.0 L 57.0,9.0 L 63.0,-9.0 L 69.0,9.0 L 72.0,-0.0 L 108.0,-0.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 0.0,9.0 L 108.0,9.0 L 108.0,-35.141999999999996 L 0.0,-35.141999999999996 L 0.0,9.0" style="stroke:blue;fill:none;stroke-width:0.5;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><g><g><g><symbol id="STIXTwoMathRegular_3317" viewBox="-0.108 -31.524 7.296 51.216"><path d="M 6.948 -6.228 L 6.948 -6
# ...

# %%
schemdraw.svgconfig.text = 'text'
with schemdraw.Drawing(canvas='svg') as d:
    elm.Resistor().label('$R_2$', loc='top')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" height="53.342pt" width="117.2pt" viewBox="-4.6 -39.742 117.2 53.342"><rect x="-4.6" y="-39.742" width="117.19999999999999" height="53.342" style="fill:none; stroke-width:0.5; stroke:black;" /><rect x="0.0" y="-35.141999999999996" width="108.0" height="44.141999999999996" style="fill:none; stroke-width:1; stroke:red;" /><path d="M 0.0,-0.0 L 36.0,-0.0 L 39.0,-9.0 L 45.0,9.0 L 50.99999999999999,-9.0 L 57.0,9.0 L 63.0,-9.0 L 69.0,9.0 L 72.0,-0.0 L 108.0,-0.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 0.0,9.0 L 108.0,9.0 L 108.0,-35.141999999999996 L 0.0,-35.141999999999996 L 0.0,9.0" style="stroke:blue;fill:none;stroke-width:0.5;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><text x="54.0" y="-38.6" dominant-baseline="ideographic" fill="black" font-size="26" font-family="sans" text-anchor="m
# ...

# %%
with schemdraw.Drawing(canvas='matplotlib') as d:
    elm.Resistor().label('$R_2$', loc='bot')

# %%
schemdraw.svgconfig.text = 'path'
with schemdraw.Drawing(canvas='svg') as d:
    elm.Resistor().label('$R_2$', loc='bot')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" height="53.342pt" width="117.2pt" viewBox="-4.6 -13.6 117.2 53.342"><rect x="-4.6" y="-13.6" width="117.19999999999999" height="53.342" style="fill:none; stroke-width:0.5; stroke:black;" /><rect x="0.0" y="-9.0" width="108.0" height="44.141999999999996" style="fill:none; stroke-width:1; stroke:red;" /><path d="M 0.0,-0.0 L 36.0,-0.0 L 39.0,-9.0 L 45.0,9.0 L 50.99999999999999,-9.0 L 57.0,9.0 L 63.0,-9.0 L 69.0,9.0 L 72.0,-0.0 L 108.0,-0.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 0.0,35.141999999999996 L 108.0,35.141999999999996 L 108.0,-9.0 L 0.0,-9.0 L 0.0,35.141999999999996" style="stroke:blue;fill:none;stroke-width:0.5;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><g><g><g><symbol id="STIXTwoMathRegular_3317" viewBox="-0.108 -31.524 7.296 51.216"><path d="M 6.948 -6.228 L 6.948 -6.228
# ...

# %%
schemdraw.svgconfig.text = 'text'
with schemdraw.Drawing(canvas='svg') as d:
    elm.Resistor().label('$R_2$', loc='bot')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" height="53.342pt" width="117.2pt" viewBox="-4.6 -13.6 117.2 53.342"><rect x="-4.6" y="-13.6" width="117.19999999999999" height="53.342" style="fill:none; stroke-width:0.5; stroke:black;" /><rect x="0.0" y="-9.0" width="108.0" height="44.141999999999996" style="fill:none; stroke-width:1; stroke:red;" /><path d="M 0.0,-0.0 L 36.0,-0.0 L 39.0,-9.0 L 45.0,9.0 L 50.99999999999999,-9.0 L 57.0,9.0 L 63.0,-9.0 L 69.0,9.0 L 72.0,-0.0 L 108.0,-0.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 0.0,35.141999999999996 L 108.0,35.141999999999996 L 108.0,-9.0 L 0.0,-9.0 L 0.0,35.141999999999996" style="stroke:blue;fill:none;stroke-width:0.5;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><text x="54.0" y="-13.4" dominant-baseline="hanging" fill="black" font-size="26" font-family="sans" text-anchor="middle"><
# ...

# %%
schemdraw.svgconfig.text = 'path'

# %%
with schemdraw.Drawing(canvas='svg'):
    elm.Resistor().label('ABC\nXYZg', fontsize=20, ofst=0, valign='base')
    elm.Resistor().label('ABC\nXYZg', fontsize=20, ofst=0, valign='bottom')
    elm.Resistor().label('ABC\nXYZg', fontsize=20, ofst=0, valign='center')
    elm.Resistor().label('ABC\nXYZg', fontsize=20, ofst=0, valign='top')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" height="85.08pt" width="441.20000000000005pt" viewBox="-4.6 -51.54 441.20000000000005 85.08"><rect x="-4.6" y="-51.54" width="441.20000000000005" height="85.08" style="fill:none; stroke-width:0.5; stroke:black;" /><rect x="0.0" y="-46.94" width="432.0" height="75.88" style="fill:none; stroke-width:1; stroke:red;" /><path d="M 0.0,-0.0 L 36.0,-0.0 L 39.0,-9.0 L 45.0,9.0 L 50.99999999999999,-9.0 L 57.0,9.0 L 63.0,-9.0 L 69.0,9.0 L 72.0,-0.0 L 108.0,-0.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 0.0,9.0 L 108.0,9.0 L 108.0,-42.36 L 0.0,-42.36 L 0.0,9.0" style="stroke:blue;fill:none;stroke-width:0.5;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 108.0,-0.0 L 144.0,-0.0 L 147.0,-9.0 L 153.0,9.0 L 158.99999999999997,-9.0 L 165.0,9.0 L 171.0,-9.0 L 176.99999999999997,9.0 L 180.0,-0.0 
# ...

# %%
with schemdraw.Drawing(canvas='matplotlib'):
    elm.Resistor().label('ABC\nXYZg', fontsize=20, ofst=0, valign='base')
    elm.Resistor().label('ABC\nXYZg', fontsize=20, ofst=0, valign='bottom')
    elm.Resistor().label('ABC\nXYZg', fontsize=20, ofst=0, valign='center')
    elm.Resistor().label('ABC\nXYZg', fontsize=20, ofst=0, valign='top')

# %%
with schemdraw.Drawing(canvas='svg'):
    elm.Resistor().down().label('ABC\nXYZg', fontsize=20, ofst=0, halign='left')
    elm.Resistor().label('ABC\nXYZg', fontsize=20, ofst=0, halign='right')
    elm.Resistor().label('ABC\nXYZg', fontsize=20, ofst=0, halign='center')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" height="333.20000000000005pt" width="90.6pt" viewBox="-54.300000000000026 -4.6 90.6 333.20000000000005"><rect x="-54.300000000000026" y="-4.6" width="90.60000000000001" height="333.20000000000005" style="fill:none; stroke-width:0.5; stroke:black;" /><rect x="-49.700000000000024" y="-0.0" width="81.4" height="324.0" style="fill:none; stroke-width:1; stroke:red;" /><path d="M 0.0,-0.0 L -6.613092715395707e-15,36.0 L 8.999999999999993,39.0 L -9.000000000000007,45.0 L 8.999999999999991,50.99999999999999 L -9.00000000000001,57.0 L 8.999999999999988,63.0 L -9.000000000000012,69.0 L -1.3226185430791413e-14,72.0 L -1.9839278146187122e-14,108.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M -27.97,-5.1380056458227204e-15 L -27.97000000000002,108.0 L 9.96999999999998,108.0 L 9.969999999999999,1.8314592881248663e-15 L -27.
# ...

# %%
# MPL bounding box may not be correct unless exact font is provided to schemdraw.
with schemdraw.Drawing(canvas='matplotlib'):
    elm.Resistor().down().label('ABC\nXYZg', fontsize=20, ofst=0, halign='left')
    elm.Resistor().label('ABC\nXYZg', fontsize=20, ofst=0, halign='right')
    elm.Resistor().label('ABC\nXYZg', fontsize=20, ofst=0, halign='center')

# %%
text = 'Aj\nBg\nCp'
with schemdraw.Drawing(canvas='matplotlib'):
    elm.Line().label(text, fontsize=14, ofst=(0,0), valign='base')
    elm.Line().label(text, fontsize=14, ofst=(0,0), valign='center')
    elm.Line().label(text, fontsize=14, ofst=(0,0), valign='bottom')
    elm.Line().label(text, fontsize=14, ofst=(0,0), valign='top')

# %%
schemdraw.svgconfig.text = 'path'
with schemdraw.Drawing(canvas='svg'):
    elm.Line().label(text, fontsize=14, ofst=(0,0), valign='base')
    elm.Line().label(text, fontsize=14, ofst=(0,0), valign='center')
    elm.Line().label(text, fontsize=14, ofst=(0,0), valign='bottom')
    elm.Line().label(text, fontsize=14, ofst=(0,0), valign='top')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" height="90.25999999999999pt" width="441.20000000000005pt" viewBox="-4.6 -45.129999999999995 441.20000000000005 90.25999999999999"><rect x="-4.6" y="-45.129999999999995" width="441.20000000000005" height="90.25999999999999" style="fill:none; stroke-width:0.5; stroke:black;" /><rect x="0.0" y="-40.529999999999994" width="432.0" height="81.05999999999999" style="fill:none; stroke-width:1; stroke:red;" /><path d="M 0.0,-0.0 L 54.0,-0.0 L 108.0,-0.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 0.0,3.080000000000002 L 108.0,3.080000000000002 L 108.0,-37.449999999999996 L 0.0,-37.449999999999996 L 0.0,3.080000000000002" style="stroke:blue;fill:none;stroke-width:0.5;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 108.0,-0.0 L 162.0,-0.0 L 216.0,-0.0" style="stroke:black;fill:none;stroke-wi
# ...

# %%
schemdraw.svgconfig.text = 'text'
with schemdraw.Drawing(canvas='svg'):
    elm.Line().label(text, fontsize=14, ofst=(0,0), valign='base')
    elm.Line().label(text, fontsize=14, ofst=(0,0), valign='center')
    elm.Line().label(text, fontsize=14, ofst=(0,0), valign='bottom')
    elm.Line().label(text, fontsize=14, ofst=(0,0), valign='top')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" height="90.25999999999999pt" width="441.20000000000005pt" viewBox="-4.6 -45.129999999999995 441.20000000000005 90.25999999999999"><rect x="-4.6" y="-45.129999999999995" width="441.20000000000005" height="90.25999999999999" style="fill:none; stroke-width:0.5; stroke:black;" /><rect x="0.0" y="-40.529999999999994" width="432.0" height="81.05999999999999" style="fill:none; stroke-width:1; stroke:red;" /><path d="M 0.0,-0.0 L 54.0,-0.0 L 108.0,-0.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 0.0,3.080000000000002 L 108.0,3.080000000000002 L 108.0,-37.449999999999996 L 0.0,-37.449999999999996 L 0.0,3.080000000000002" style="stroke:blue;fill:none;stroke-width:0.5;stroke-dasharray:-;stroke-linecap:round;stroke-linejoin:round;" /><path d="M 108.0,-0.0 L 162.0,-0.0 L 216.0,-0.0" style="stroke:black;fill:none;stroke-wi
# ...
