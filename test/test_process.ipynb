# %%
import schemdraw
import schemdraw.elements as elm
import schemdraw.dsp as dsp
import schemdraw.process as proc

# %%
d = schemdraw.Drawing(inches_per_unit=.1)

d += proc.Stirrer()
d.draw()

# %%
proc.Tank().scale(.4)

# %%
proc.Cistern(level=.1).scale(.4)

# %%
proc.PlateExchanger().scale(.4)

# %%
proc.DiscCentrifuge().scale(.4)

# %%
proc.Valve().scale(.4)

# %%
proc.HeatExchanger().scale(.4)

# %%
d = schemdraw.Drawing(inches_per_unit=.1, unit=6)
d += proc.Arrow().right()
d += (tank := proc.Tank().anchor('W'))
d += proc.Line().down().at(tank.S)
d += proc.Arrow().right()
d += (pump := proc.Pump().anchor('W'))
d += proc.Arrow().at(pump.E)
d += (heat := proc.HeatExchanger().anchor('W'))
d += proc.Arrow().right().at(heat.E)
d.draw()

# %%
proc.Boiler().scale(.4)

# %%
proc.CoolingTower().scale(.4)

# %%
proc.Filter().scale(.4)

# %%
proc.Sieve().scale(.4)
