# %%
# Various canvas options

import schemdraw
from schemdraw import elements as elm

import matplotlib.pyplot as plt
from xml.etree import ElementTree as ET

# %%
schemdraw.use('matplotlib')
elm.Resistor().label(r'1$\Omega$')

# %%
with schemdraw.Drawing() as d:
    d += elm.Resistor().label(r'1$\Omega$')

# %%
# No figure should be drawn
with schemdraw.Drawing(show=False) as d:
    d += elm.Resistor().label(r'1$\Omega$')

# %%
schemdraw.use('svg')
with schemdraw.Drawing() as d:
    d += elm.Resistor().label(r'1$\Omega$')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xml:lang="en" height="55.480000000000004pt" width="107.68pt" viewBox="-5.24 -42.14 107.68 55.480000000000004"><path d="M 0.0,-0.0 L 32.4,-0.0 L 35.099999999999994,-8.1 L 40.5,8.1 L 45.89999999999999,-8.1 L 51.3,8.1 L 56.699999999999996,-8.1 L 62.099999999999994,8.1 L 64.8,-0.0 L 97.19999999999999,-0.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-linecap:round;stroke-linejoin:round;" /><g><g><g><symbol id="STIXTwoMathRegular_4244" width="3.756" height="51.216" viewBox="0 -31.524 3.756 51.216"><path d="M 3.756 0 L 3.756 0 L 2.76 0 L 2.76 -6.348 L 1.212 -6.348 L 1.212 -6.996 Q 1.848 -7.092 2.256 -7.23 Q 2.664 -7.368 3 -7.56 L 3.756 -7.56 Z " /></symbol><use href="#STIXTwoMathRegular_4244" transform="translate(40.641 -50.218) scale(1.167)" fill="black" /></g><g><symbol id="STIXTwoMathRegular_868" width="8.772" height="51.216" viewBox="0 -31.524 8.772 51.216"><path d="M 8.496 0 L 8.496 0 L 5.364 0 L 5.364 -0.864 Q 5.928 -1.32 6.318 -1.95 Q 6.708 -2.58 6.906 -3.282 Q 7.104 -3.984 7.104 -4.644 Q 7.104 -6 6.456 -6.762 Q 5.808 -7.524 4.704 -7.524 Q 3.564 -7.524 2.904 -6.75 Q 2.244 -5.976 2.244 -4.644 Q 2.244 -3.996 2.436 -3.282 Q 2.628 -2.568 3.018 -1.932 Q 3.408 -1.296 3.984 -0.852 L 3.984 0 L 0.816 0 L 0.564 -2.124 L 0.912 -2.124 Q 1.02 -1.716 1.122 -1.464 Q 1.224 -1.212 1.41 -1.092 Q 1.596 -0.972 1.932 -0.972 L 3.024 -0.972 L 3.024 -1.044 Q 2.688 -1.296 2.322 -1.626 Q 1.956 -1.956 1.644 -2.388 Q 1.332 -2.82 1.14 -3.39 Q 0.948 -3.96 0.948 -4.692 Q 0.948 -5.688 1.428 -6.438 Q 1.908 -7.188 2.76 -7.608 Q 3.612 -8.028 4.716 -8.028 Q 5.832 -8.028 6.66 -7.608 Q 7.488 -7.188 7.944 -6.438 Q 8.4 -5.688 8.4 -4.704 Q 8.4 -3.972 8.196 -3.402 Q 7.992 -2.832 7.674 -2.394 Q 7.356 -1.956 7.002 -1.626 Q 6.648 -1.296 6.336 -1.044 L 6.336 -0.972 L 7.344 -0.972 Q 7.704 -0.972 7.89 -1.092 Q 8.076 -1.212 8.19 -1.47 Q 8.304 -1.728 8.424 -2.124 L 8.772 -2.124 Z " /></symbol><use href="#STIXTwoMathRegular_868" transform="translate(46.339 -50.218) scale(1.167)" fill="black" /></g></g></g></svg>

# %%
# No figure should be drawn
with schemdraw.Drawing(show=False) as d:
    d += elm.Resistor().label(r'1$\Omega$')

# %%
elm.Resistor().label(r'1$\Omega$')

# %%
with schemdraw.Drawing(canvas='svg') as d:
    d += elm.Resistor().label(r'1$\Omega$')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xml:lang="en" height="55.480000000000004pt" width="107.68pt" viewBox="-5.24 -42.14 107.68 55.480000000000004"><path d="M 0.0,-0.0 L 32.4,-0.0 L 35.099999999999994,-8.1 L 40.5,8.1 L 45.89999999999999,-8.1 L 51.3,8.1 L 56.699999999999996,-8.1 L 62.099999999999994,8.1 L 64.8,-0.0 L 97.19999999999999,-0.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-linecap:round;stroke-linejoin:round;" /><g><g><g><symbol id="STIXTwoMathRegular_4244" width="3.756" height="51.216" viewBox="0 -31.524 3.756 51.216"><path d="M 3.756 0 L 3.756 0 L 2.76 0 L 2.76 -6.348 L 1.212 -6.348 L 1.212 -6.996 Q 1.848 -7.092 2.256 -7.23 Q 2.664 -7.368 3 -7.56 L 3.756 -7.56 Z " /></symbol><use href="#STIXTwoMathRegular_4244" transform="translate(40.641 -50.218) scale(1.167)" fill="black" /></g><g><symbol id="STIXTwoMathRegular_868" width="8.772" height="51.216" viewBox="0 -31.524 8.772 51.216"><path d="M 8.496 0 L 8.496 0 L 5.364 0 L 5.364 -0.864 Q 5.928 -1.32 6.318 -1.95 Q 6.708 -2.58 6.906 -3.282 Q 7.104 -3.984 7.104 -4.644 Q 7.104 -6 6.456 -6.762 Q 5.808 -7.524 4.704 -7.524 Q 3.564 -7.524 2.904 -6.75 Q 2.244 -5.976 2.244 -4.644 Q 2.244 -3.996 2.436 -3.282 Q 2.628 -2.568 3.018 -1.932 Q 3.408 -1.296 3.984 -0.852 L 3.984 0 L 0.816 0 L 0.564 -2.124 L 0.912 -2.124 Q 1.02 -1.716 1.122 -1.464 Q 1.224 -1.212 1.41 -1.092 Q 1.596 -0.972 1.932 -0.972 L 3.024 -0.972 L 3.024 -1.044 Q 2.688 -1.296 2.322 -1.626 Q 1.956 -1.956 1.644 -2.388 Q 1.332 -2.82 1.14 -3.39 Q 0.948 -3.96 0.948 -4.692 Q 0.948 -5.688 1.428 -6.438 Q 1.908 -7.188 2.76 -7.608 Q 3.612 -8.028 4.716 -8.028 Q 5.832 -8.028 6.66 -7.608 Q 7.488 -7.188 7.944 -6.438 Q 8.4 -5.688 8.4 -4.704 Q 8.4 -3.972 8.196 -3.402 Q 7.992 -2.832 7.674 -2.394 Q 7.356 -1.956 7.002 -1.626 Q 6.648 -1.296 6.336 -1.044 L 6.336 -0.972 L 7.344 -0.972 Q 7.704 -0.972 7.89 -1.092 Q 8.076 -1.212 8.19 -1.47 Q 8.304 -1.728 8.424 -2.124 L 8.772 -2.124 Z " /></symbol><use href="#STIXTwoMathRegular_868" transform="translate(46.339 -50.218) scale(1.167)" fill="black" /></g></g></g></svg>

# %%
with schemdraw.Drawing(canvas='matplotlib') as d:
    d += elm.Resistor().label(r'1$\Omega$')

# %%
fig, ax = plt.subplots()
ax.plot([0,1,2,3,4,5],[0,1,0,-1,0,1], marker='o', ls='')
ax.set_aspect('equal')
with schemdraw.Drawing(canvas=ax) as d:
    elm.Resistor()

# %%
svg = ET.Element('svg')
svg.set('xmlns', 'http://www.w3.org/2000/svg')
svg.set('xml:lang', 'en')
svg.set('height', f'100')
svg.set('width', f'300')
svg.set('viewBox', f'0 0 300 100')
circ = ET.SubElement(svg, 'circle')
circ.set('cx', '20')
circ.set('cy', '25')
circ.set('r', '25')
circ.set('fill', 'orange')

with schemdraw.Drawing(canvas=svg) as d:
    d.config(inches_per_unit=.5)
    d += elm.Resistor().label(r'1$\Omega$').at((1,-1))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xml:lang="en" height="100" width="300" viewBox="0 0 300 100"><circle cx="20" cy="25" r="25" fill="orange" /><path d="M 32.4,32.4 L 64.8,32.4 L 67.49999999999999,24.299999999999997 L 72.89999999999999,40.5 L 78.3,24.299999999999997 L 83.69999999999999,40.5 L 89.1,24.299999999999997 L 94.49999999999999,40.5 L 97.19999999999999,32.4 L 129.6,32.4" style="stroke:black;fill:none;stroke-width:2.0;stroke-linecap:round;stroke-linejoin:round;" /><g><g><g><symbol id="STIXTwoMathRegular_4244" width="3.756" height="51.216" viewBox="0 -31.524 3.756 51.216"><path d="M 3.756 0 L 3.756 0 L 2.76 0 L 2.76 -6.348 L 1.212 -6.348 L 1.212 -6.996 Q 1.848 -7.092 2.256 -7.23 Q 2.664 -7.368 3 -7.56 L 3.756 -7.56 Z " /></symbol><use href="#STIXTwoMathRegular_4244" transform="translate(73.041 -17.818) scale(1.167)" fill="black" /></g><g><symbol id="STIXTwoMathRegular_868" width="8.772" height="51.216" viewBox="0 -31.524 8.772 51.216"><path d="M 8.496 0 L 8.496 0 L 5.364 0 L 5.364 -0.864 Q 5.928 -1.32 6.318 -1.95 Q 6.708 -2.58 6.906 -3.282 Q 7.104 -3.984 7.104 -4.644 Q 7.104 -6 6.456 -6.762 Q 5.808 -7.524 4.704 -7.524 Q 3.564 -7.524 2.904 -6.75 Q 2.244 -5.976 2.244 -4.644 Q 2.244 -3.996 2.436 -3.282 Q 2.628 -2.568 3.018 -1.932 Q 3.408 -1.296 3.984 -0.852 L 3.984 0 L 0.816 0 L 0.564 -2.124 L 0.912 -2.124 Q 1.02 -1.716 1.122 -1.464 Q 1.224 -1.212 1.41 -1.092 Q 1.596 -0.972 1.932 -0.972 L 3.024 -0.972 L 3.024 -1.044 Q 2.688 -1.296 2.322 -1.626 Q 1.956 -1.956 1.644 -2.388 Q 1.332 -2.82 1.14 -3.39 Q 0.948 -3.96 0.948 -4.692 Q 0.948 -5.688 1.428 -6.438 Q 1.908 -7.188 2.76 -7.608 Q 3.612 -8.028 4.716 -8.028 Q 5.832 -8.028 6.66 -7.608 Q 7.488 -7.188 7.944 -6.438 Q 8.4 -5.688 8.4 -4.704 Q 8.4 -3.972 8.196 -3.402 Q 7.992 -2.832 7.674 -2.394 Q 7.356 -1.956 7.002 -1.626 Q 6.648 -1.296 6.336 -1.044 L 6.336 -0.972 L 7.344 -0.972 Q 7.704 -0.972 7.89 -1.092 Q 8.076 -1.212 8.19 -1.47 Q 8.304 -1.728 8.424 -2.124 L 8.772 -2.124 Z " /></symbol><use href="#STIXTwoMathRegular_868" transform="translate(78.739 -17.818) scale(1.167)" fill="black" /></g></g></g></svg>

# %%
d = schemdraw.Drawing()
d += elm.Resistor()
d.draw(showframe=True, canvas='svg')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xml:lang="en" height="26.679999999999996pt" width="107.68pt" viewBox="-5.24 -13.339999999999998 107.68 26.679999999999996"><rect x="-5.24" y="-13.339999999999998" width="103.68" height="22.679999999999996" style="fill:none; stroke-width:1; stroke:black;" /><path d="M 0.0,-0.0 L 32.4,-0.0 L 35.099999999999994,-8.1 L 40.5,8.1 L 45.89999999999999,-8.1 L 51.3,8.1 L 56.699999999999996,-8.1 L 62.099999999999994,8.1 L 64.8,-0.0 L 97.19999999999999,-0.0" style="stroke:black;fill:none;stroke-width:2.0;stroke-linecap:round;stroke-linejoin:round;" /></svg>

# %%
d = schemdraw.Drawing()
d += elm.Resistor()
d.draw(showframe=True, canvas='matplotlib')
